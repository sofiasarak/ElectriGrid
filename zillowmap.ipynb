# %% [markdown]
# # Initial Zillow GeoPackage Exploration
#
# **Running all of this code will take approximately 30 minutes**
#
# Load in necessary libraries.

# %%
import os 
import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr

import matplotlib.pyplot as plt

# %% [markdown]
# There are issues with reading in data. The next line of code was provided by Kat Le, the Bren Applications Manager. She explained the error that occurs when trying to read in geospatial data without this code occurs because the workbench cannot find PROJ at the expected location. This line of code pointed PROJ_LIB to a location on the machine where PROJ actually exists. **We can consider making our own environment for the ElectriGrid project.**

# %%
os.environ['PROJ_LIB'] = '/opt/anaconda3/share/proj'

# %%
# read in the zillow geo data 
fp = os.path.join('data', 'final_zillow.gpkg')
zillowmap = gpd.read_file(fp)

# %% [markdown]
# Note: The data takes approximately 10 minutes to read in.

# %%
# view the data frame
zillowmap.head()
# Out:
#     type    year  room  heat  cool   own   unit     value sqft_type    sqft  \
# 0  Multi  2003.0   1.0  None  None     I  224.0  491943.0    living  1003.0
# 1  Multi  2003.0   1.0  None  None  None  224.0  240117.0    living   936.0
# 2  Multi  2003.0   1.0  None  None     I  224.0  261770.0    living   997.0
# 3  Multi  2003.0   1.0  None  None  None  224.0  223337.0    living  1002.0
# 4  Multi  2003.0   1.0  None  None  None  224.0  241347.0    living  1003.0
#
#    ID        GEOID p_ID     area   code                        geometry
# 0   3  06001403302  468  PGE/SCE  RR106  POINT (564447.371 4183243.435)
# 1   4  06001403302  468  PGE/SCE  RR106  POINT (564447.371 4183243.435)
# 2   5  06001403302  468  PGE/SCE  RR106  POINT (564447.371 4183243.435)
# 3   6  06001403302  468  PGE/SCE  RR106  POINT (564447.371 4183243.435)
# 4   7  06001403302  468  PGE/SCE  RR106  POINT (564449.237 4183218.817)

# %%
# check the crs
zillowmap.crs
# Out:
# <Projected CRS: EPSG:26910>
# Name: NAD83 / UTM zone 10N
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: UTM zone 10N
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# initial plot 
zillowmap.plot()
# Out:
# <Axes: >

# %% [markdown]
# Note: The initial plot takes approximately 5 minutes to run.

# %% [markdown]
# ### Zillow geodata issues
# The Zillow data seems to include data from outside of California including a data point in Alaska. Exploring how to fix this geospatially using a boundary of California below

# %%
# read in California boundary data
fp = os.path.join('data', 'ca_state_boundary', 'ca_state_boundary.shp')
ca= gpd.read_file(fp)

# %%
# initial plot of the CA boundary
ca.plot()
# Out:
# <Axes: >

# %%
# check the ca crs 
ca.crs
# Out:
# <Geographic 2D CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84" ...>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (Degree)
# - lat[north]: Latitude (Degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# check if the crs match
ca.crs == zillowmap.crs
# Out:
# False

# %% [markdown]
# ### CRS Matching
# The CRS of the Zillowmap and the CA boundary do not match. To decide what CRS to keep we'll explore whether the CRS of each geodata is projected versus geographic.

# %%
# check if zillowmap is in a projected CRS
zillowmap.crs.is_projected
# Out:
# True

# %% [markdown]
# We'll keep the CRS of the Zillowmap since its projected and much larger than the California boundary.

# %%
# change the CA boundary to the zillowmap CRS
ca = ca.to_crs(zillowmap.crs)

# %%
# Use an assert statement to make sure the CRS match
assert ca.crs == zillowmap.crs

# %% [markdown]
# # Clip for only CA Zillow data

# %%
# clip zillow data to ca
ca_zillow = gpd.clip(zillowmap, ca)

# %% [markdown]
# # Map the CA Zillow data

# %%
fig, ax = plt.subplots(figsize=(11, 5))
ax.axis('off')

ca.plot(ax = ax, color = 'whitesmoke', edgecolor='0.7')
ca_zillow.plot(ax=ax,
               zorder = 1, # specify layer plotting order
               column = 'type',
               legend = True,
               alpha = 0.4,
               legend_kwds={'title': "Housing Types", 
                            'loc': 'upper left',
                            'bbox_to_anchor':(0,0.9),
                            'fontsize':'small'})

ax.set_title('Zillow CA data', fontsize = 14, fontweight = 'bold')

plt.show()
# Out:
# <Axes: >

# %% [markdown]
# Note: This code takes approximately 15 minutes to run.
